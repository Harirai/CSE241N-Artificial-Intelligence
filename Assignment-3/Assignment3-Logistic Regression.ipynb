# %% [markdown]
# # Assignment 3 - Logistic Regression
#
# Given the marks of a student in two subjects we want to predict whether he will get admission or not.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from model import *
from utils import *

# %%
file = 'marks.csv'

# %%
X, Y, admitted, not_admitted = load_data(file)

# %% [markdown]
# ### Visualize dataset

# %%
visualize_data(admitted, not_admitted)

# %% [markdown]
# ### Train the model

# %%
# Try changing the learning rate and number of iterations

##################
lr = 0.00104
num_iters =100000
##################

model = LogisticRegression() 
model.train(X, Y, lr,num_iters,10)
print("Model Accuracy: {}".format(model.accuracy(X,Y)))
# Out:
# Iteration 0 of 100000. Loss: 85.046234 LR: 0.001040
# Iteration 10000 of 100000. Loss: 0.615312 LR: 0.001040
# Iteration 20000 of 100000. Loss: 0.568204 LR: 0.001040
# Iteration 30000 of 100000. Loss: 0.532320 LR: 0.001040
# Iteration 40000 of 100000. Loss: 0.502327 LR: 0.001040
# Iteration 50000 of 100000. Loss: 0.477095 LR: 0.001040
# Iteration 60000 of 100000. Loss: 0.455708 LR: 0.001040
# Iteration 70000 of 100000. Loss: 0.437439 LR: 0.001040
# Iteration 80000 of 100000. Loss: 0.421711 LR: 0.001040
# Iteration 90000 of 100000. Loss: 0.408071 LR: 0.001040
# Model Accuracy: 0.9

# %% [markdown]
# ### Visualize Decision Boundary

# %%
visualize_decision_boundary(admitted, not_admitted, X, model.weights.flatten())

# %% [markdown]
# ### Save hyperparameters

# %%
save_hyperparameters(lr, num_iters)
